# %%
import skimage
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from skimage import io

# %matplotlib inline

# %% [markdown]
# ### 图像shape

# %%
cat = io.imread('./datasets/cat.png')
dog = io.imread('./datasets/dog.png')
df = pd.DataFrame(['Cat', 'Dog'], columns=['Image'])

print(cat.shape, dog.shape)
# Out:
# (168, 300, 3) (168, 300, 3)

# %%
cat #0-255,越小的值代表越暗，越大的值越亮
# Out:
# array([[[114, 105,  90],
#         [113, 104,  89],
#         [112, 103,  88],
#         ...,
#         [127, 130, 121],
#         [130, 133, 124],
#         [133, 136, 127]],
#
#        [[113, 104,  89],
#         [112, 103,  88],
#         [111, 102,  87],
#         ...,
#         [129, 132, 125],
#         [132, 135, 128],
#         [135, 138, 131]],
#
#        [[111, 102,  87],
#         [111, 102,  87],
#         [110, 101,  86],
#         ...,
#         [132, 134, 133],
#         [136, 138, 137],
#         [139, 141, 140]],
#
#        ...,
#
#        [[ 32,  26,  28],
#         [ 32,  26,  28],
#         [ 30,  24,  26],
#         ...,
#         [131, 131, 131],
#         [131, 131, 131],
#         [130, 130, 130]],
#
#        [[ 33,  27,  29],
#         [ 32,  26,  28],
#         [ 31,  25,  27],
#         ...,
#         [131, 131, 131],
#         [131, 131, 131],
#         [130, 130, 130]],
#
#        [[ 33,  27,  29],
#         [ 32,  26,  28],
#         [ 31,  25,  27],
#         ...,
#         [131, 131, 131],
#         [131, 131, 131],
#         [130, 130, 130]]], dtype=uint8)

# %%
#coffee = skimage.transform.resize(coffee, (300, 451), mode='reflect')
fig = plt.figure(figsize = (8,4))
ax1 = fig.add_subplot(1,2, 1)
ax1.imshow(cat)

ax2 = fig.add_subplot(1,2, 2)
ax2.imshow(dog)

# %%
dog_r = dog.copy() # Red Channel
dog_r[:,:,1] = dog_r[:,:,2] = 0 # set G,B pixels = 0
dog_g = dog.copy() # Green Channel
dog_g[:,:,0] = dog_r[:,:,2] = 0 # set R,B pixels = 0
dog_b = dog.copy() # Blue Channel
dog_b[:,:,0] = dog_b[:,:,1] = 0 # set R,G pixels = 0

plot_image = np.concatenate((dog_r, dog_g, dog_b), axis=1)
plt.figure(figsize = (10,4))
plt.imshow(plot_image)

# %%
dog_r[:3]
# Out:
# array([[[160,   0,   0],
#         [160,   0,   0],
#         [160,   0,   0],
#         ...,
#         [113,   0,   0],
#         [113,   0,   0],
#         [112,   0,   0]],
#
#        [[160,   0,   0],
#         [160,   0,   0],
#         [160,   0,   0],
#         ...,
#         [113,   0,   0],
#         [113,   0,   0],
#         [112,   0,   0]],
#
#        [[160,   0,   0],
#         [160,   0,   0],
#         [160,   0,   0],
#         ...,
#         [113,   0,   0],
#         [113,   0,   0],
#         [112,   0,   0]]], dtype=uint8)

# %% [markdown]
# ### 灰度图

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

dog_ = Image.open('./datasets/dog.png')
cat_ = Image.open('./datasets/cat.png')
dog_ = np.array(dog_)
cat_ = np.array(cat_)
if cat_.ndim == 3:
    cat_ = cat_[:,:,0]

if dog_.ndim == 3:
    dog_ = dog_[:,:,0]
plt.subplot(221); plt.imshow(cat_, cmap ='gray')
plt.subplot(222); plt.imshow(dog_, cmap = plt.cm.gray)
plt.show()

# %%
d = np.array(Image.open('./datasets/dog.png'))
plt.imshow(d.mean(axis = 2), cmap ='gray')
